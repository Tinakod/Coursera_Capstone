# %% [markdown]
# # The battle of the Neighbourhoods- Week 1

# %% [markdown]
# ## Introduction and Business Plan

# %% [markdown]
# ### Problem background:

# %% [markdown]
# London is the capital and largest city of England and the United Kingdom. The city stands on the River Thames in the south-east of England, at the head of its 50-mile (80 km) estuary leading to the North Sea. London has been a major settlement for two millennia.London is an international centre of business, finance, arts, and culture, and is recognized as one of the most **multicultural** and **cosmopolitan** cities in the world.

# %% [markdown]
# This means that the market is highly competitive meaning that the cost of doing business is one of the highest. But what about those who don't have enough money, but still want to open a restaurant outside inner city limits? Where will it be cheapest and will have enough people living around to be popular? Where the competition is not too overwhelming? Therefore, any new business setting must be analyzed thorougly so as to have the most profit of it. **Statistical analysis** of the proper data is mandatory, because it will certainly reduce the risk of failure.

# %% [markdown]
# ### Problem description:

# %% [markdown]
# A restaurant is a business which prepares and serves food, and other services to costumers in return for money. London is famous for the excellent cuisine and the vast variety of restaurants/bars/pubs influenced by the different cuisines/cultures that exist around the world. In order to survive in such a competitive environment, a new restaurant must take into consideration various data, and come up with a strategical plan.

# %% [markdown]
# To recommend the correct location, a little company called *AC Company* has appointed me to lead of the Data Science team. The objective is to locate and recommend to the management which neighborhood of London will be best choice to start a food/drink business.

# %% [markdown]
# My analysis for the best location will be based in focusing of the neighbourhood/area outside inner cityt limits, but with high population,and minimum max rent.

# %% [markdown]
# ### Data description:

# %% [markdown]
# *Based on the description of the problem, factors that may impact the decision are:*
#
# 1. Demographic information: population income, max rent
# 2. List of venues through 4Square

# %% [markdown]
# I will need a list of neighbourhoods in London broken down by postal code, which i will access through wikipedia and load to my dataset.
# https://en.wikipedia.org/wiki/List_of_London_boroughs'

# %% [markdown]
# I will need a list of population by postal code, which i will import through https://en.wikipedia.org/wiki/List_of_London_boroughs'

# %% [markdown]
# I will need a list of all London venues by postal code, which I will access through the 4SQUARE API.

# %% [markdown]
# Finally, I will combine all of these to cluster and geo spatial map of the results showing the best neighbourhood to open a new food/drink business in London.
